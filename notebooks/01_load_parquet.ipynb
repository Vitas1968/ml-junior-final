# %%
import numpy as np
import pyarrow
import pandas as pd

print("numpy:", np.__version__)
print("pyarrow:", pyarrow.__version__)
print("pandas:", pd.__version__)
# Out:
# numpy: 1.26.4
# pyarrow: 14.0.2
# pandas: 3.0.0

# %%
import pandas as pd
df = pd.read_parquet("../data/raw/train_data_0.pq")
df.head()
# Out:
#    id  rn  pre_since_opened  pre_since_confirmed  pre_pterm  pre_fterm  \
# 0   0   1                18                    9          2          3
# 1   0   2                18                    9         14         14
# 2   0   3                18                    9          4          8
# 3   0   4                 4                    1          9         12
# 4   0   5                 5                   12         15          2
#
#    pre_till_pclose  pre_till_fclose  pre_loans_credit_limit  \
# 0               16               10                      11
# 1               12               12                       0
# 2                1               11                      11
# 3               16                7                      12
# 4               11               12                      10
#
#    pre_loans_next_pay_summ  ...  enc_paym_21  enc_paym_22  enc_paym_23  \
# 0                        3  ...            3            3            3
# ...

# %%
# импорт и окружение
import sys
from pathlib import Path

# добавляем корень проекта в PYTHONPATH
PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))

# %%
from src.data_loading import build_base_dataset

# %%
df = build_base_dataset()

# %%
df.shape
# Out:
# (3000000, 61)

# %%
df.head()
# Out:
#    id   rn  pre_since_opened  pre_since_confirmed  pre_pterm  pre_fterm  \
# 0   0  5.5          8.100000             7.600000   7.100000   7.500000
# 1   1  7.5         11.428571             7.642857   6.642857   7.928571
# 2   2  2.0          8.333333            10.666667   7.000000   6.000000
# 3   3  8.0          7.000000             7.333333   7.600000   7.800000
# 4   4  1.0         12.000000             9.000000   4.000000   8.000000
#
#    pre_till_pclose  pre_till_fclose  pre_loans_credit_limit  \
# 0        11.400000        10.700000                9.600000
# 1        10.071429         7.000000                8.142857
# 2         5.000000         9.000000                1.666667
# 3         5.200000         8.133333                9.866667
# 4         1.000000        11.000000               12.000000
#
#    pre_loans_next_pay_summ  ...  enc_paym_21  enc_paym_22  enc_paym_23  \
# 0                 3.100000  ...     2.400000     2.400000     2.400000
# ...

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 61 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   id                             int64
#  1   rn                             float64
#  2   pre_since_opened               float64
#  3   pre_since_confirmed            float64
#  4   pre_pterm                      float64
#  5   pre_fterm                      float64
#  6   pre_till_pclose                float64
#  7   pre_till_fclose                float64
#  8   pre_loans_credit_limit         float64
#  9   pre_loans_next_pay_summ        float64
#  10  pre_loans_outstanding          float64
#  11  pre_loans_total_overdue        float64
#  12  pre_loans_max_overdue_sum      float64
#  13  pre_loans_credit_cost_rate     float64
#  14  pre_loans5                     float64
#  15  pre_loans530                   float64
#  16  pre_loans3060                  float64
# ...

# %%
df.isna().sum().sort_values(ascending=False).head(20)
# Out:
# id             0
# enc_paym_1     0
# enc_paym_3     0
# enc_paym_4     0
# enc_paym_5     0
# enc_paym_6     0
# enc_paym_7     0
# enc_paym_8     0
# enc_paym_9     0
# enc_paym_10    0
# enc_paym_11    0
# enc_paym_12    0
# enc_paym_13    0
# enc_paym_14    0
# enc_paym_15    0
# enc_paym_16    0
# enc_paym_17    0
# enc_paym_18    0
# enc_paym_19    0
# enc_paym_20    0
# dtype: int64

# %%
output_path = PROJECT_ROOT / "data" / "processed" / "dataset.pkl"
output_path.parent.mkdir(parents=True, exist_ok=True)

df.to_pickle(output_path)

output_path
# Out:
# WindowsPath('C:/Users/vdorofeev/PycharmProjects/JupyterProject/ML Junior final/data/processed/dataset.pkl')

# %%
df["id"].nunique()
# Out:
# 3000000

# %%
df.duplicated(subset="id").sum()
# Out:
# 0

# %%
assert df["id"].is_unique, "ID не уникален — ошибка агрегации"
